# %% [markdown]
# # Pretest for Telkomsel Data Science Academy
# ## This document is solution of pre-test for Basic Python Programming class at Telkomsel
# ## Student: Johan Ginting
# ## Dataset: Churn [Churn.csv](https://www.openml.org/d/40701)
# ## Objective: To explore Churn data using statistics and Python
# ## Date: 16 October 2019

# %%
import pandas as pd
import numpy as np

# %%
customers = pd.read_csv("churn.csv")
customers.head()
# Out:
#    state  account_length  area_code  phone_number  international_plan  \
# 0     16             128        415          2845                   0
# 1     35             107        415          2301                   0
# 2     31             137        415          1616                   0
# 3     35              84        408          2510                   1
# 4     36              75        415           155                   1
#
#    voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                1                     25              265.1              110
# 1                1                     26              161.6              123
# 2                0                      0              243.4              114
# 3                0                      0              299.4               71
# 4                0                      0              166.7              113
#
#    total_day_charge  ...  total_eve_calls  total_eve_charge  \
# ...

# %%
#column
print("kolom:",len(customers.columns))
#row
print("baris:",len(customers))
# Out:
# kolom: 21
# baris: 5000

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 21 columns):
# state                            5000 non-null int64
# account_length                   5000 non-null int64
# area_code                        5000 non-null int64
# phone_number                     5000 non-null int64
# international_plan               5000 non-null int64
# voice_mail_plan                  5000 non-null int64
# number_vmail_messages            5000 non-null int64
# total_day_minutes                5000 non-null float64
# total_day_calls                  5000 non-null int64
# total_day_charge                 5000 non-null float64
# total_eve_minutes                5000 non-null float64
# total_eve_calls                  5000 non-null int64
# total_eve_charge                 5000 non-null float64
# total_night_minutes              5000 non-null float64
# total_night_calls                5000 non-null int64
# ...

# %%
customers.columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class'],
#       dtype='object')

# %%
churn=customers[customers.class==1]
#imdb_2015=imdb[imdb.title_year==2015]
# Out:
#   File "<ipython-input-72-1077426ab899>", line 1
#     churn=customers[customers.class==1]
#                                   ^
# SyntaxError: invalid syntax

# %%
customers.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# phone_number                     0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# class                            0
# dtype: int64

# %%
customers.select_dtypes(exclude='object').columns
# Out:
# Index(['state', 'account_length', 'area_code', 'phone_number',
#        'international_plan', 'voice_mail_plan', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls', 'class'],
#       dtype='object')

# %%
numeric_variable = ['international_plan', 'voice_mail_plan', 'number_vmail_messages',
       'total_day_minutes', 'total_day_calls', 'total_day_charge',
       'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
       'total_night_minutes', 'total_night_calls', 'total_night_charge',
       'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
       'number_customer_service_calls', 'class']

# %% [markdown]
# # T-Test of Data

# %%
from scipy import stats

# %%
churn = customers[customers['class']==1]

# %%
nonchurn = customers[customers['class']==0]

# %%
print(churn)
print(nonchurn)
# Out:
#       state  account_length  area_code  phone_number  international_plan  \
# 10       15              65        415           100                   0
# 15       34             161        415          1268                   0
# 21        5              77        408          3452                   0
# 33        3              12        408          1723                   0
# 41       20             135        408          2906                   1
# 48       13             119        415          3685                   0
# 54       50              87        415          1365                   0
# 57        5             121        408          2254                   0
# 69       43             150        510          2448                   0
# 76        7              82        415          2439                   0
# 77       34             144        408          1719                   0
# 84       43             106        510          3542                   0
# ...

# %% [markdown]
# # Significant Variables

# %%
for item in numeric_variable:
    a = stats.ttest_ind(churn[item], nonchurn[item],  equal_var = False)
    if (a.pvalue<0.05):
        print(item)
# Out:
# international_plan
# voice_mail_plan
# number_vmail_messages
# total_day_minutes
# total_day_charge
# total_eve_minutes
# total_eve_charge
# total_night_minutes
# total_night_charge
# total_intl_minutes
# total_intl_calls
# total_intl_charge
# number_customer_service_calls
# class

# %% [markdown]
# # Correlation Value

# %%
customers.corr(method='kendall')
# Out:
#                                   state  account_length  area_code  \
# state                          1.000000        0.006757   0.008825
# account_length                 0.006757        1.000000  -0.019424
# area_code                      0.008825       -0.019424   1.000000
# phone_number                   0.011216        0.001131  -0.008522
# international_plan             0.006172        0.015966   0.027671
# voice_mail_plan               -0.024402       -0.004062   0.003928
# number_vmail_messages         -0.021751       -0.007527   0.003534
# total_day_minutes              0.006284        0.003004   0.000060
# total_day_calls               -0.004106        0.017063  -0.001654
# total_day_charge               0.006284        0.003004   0.000060
# total_eve_minutes              0.006180       -0.008267   0.002380
# total_eve_calls               -0.003818        0.005316  -0.014041
# total_eve_charge               0.006180       -0.008265   0.002390
# ...

# %%
abs(customers[numeric_variable].corr()['class']).sort_values()
# Out:
# total_eve_calls                  0.006284
# total_night_calls                0.006986
# total_day_calls                  0.016130
# total_night_charge               0.045673
# total_night_minutes              0.045677
# total_intl_calls                 0.046893
# total_intl_charge                0.063275
# total_intl_minutes               0.063285
# total_eve_charge                 0.089282
# total_eve_minutes                0.089288
# number_vmail_messages            0.097633
# voice_mail_plan                  0.110698
# total_day_charge                 0.207700
# total_day_minutes                0.207705
# number_customer_service_calls    0.212564
# international_plan               0.259123
# class                            1.000000
# Name: class, dtype: float64

# %% [markdown]
# chosen features/variables :
# voice_mail_plan
# total_day_charge
# total_day_minutes
# number_customer_service_calls
# international_plan

# %% [markdown]
# # Perbedaan antar Variables untuk Churned dan Non Churned

# %%
churn[['voice_mail_plan', 'total_day_charge', 'total_day_minutes', 'number_customer_service_calls', 
       'international_plan']].mean().round(2)
# Out:
# voice_mail_plan                    0.14
# total_day_charge                  35.34
# total_day_minutes                207.87
# number_customer_service_calls      2.25
# international_plan                 0.28
# dtype: float64

# %%
nonchurn[['voice_mail_plan', 'total_day_charge', 'total_day_minutes', 'number_customer_service_calls', 
       'international_plan']].mean().round(2)
# Out:
# voice_mail_plan                    0.28
# total_day_charge                  29.88
# total_day_minutes                175.75
# number_customer_service_calls      1.46
# international_plan                 0.06
# dtype: float64

# %% [markdown]
# # Perbedaan Call ke Customer Services

# %%
print("Average Customer Services Calls untuk Churned ", churn[['number_customer_service_calls']].mean().round(2), " Sedangkan untuk yang Non Churned ",
nonchurn[['number_customer_service_calls']].mean().round(2) )
# Out:
# Average Customer Services Calls untuk Churned  number_customer_service_calls    2.25
# dtype: float64  Sedangkan untuk yang Non Churned  number_customer_service_calls    1.46
# dtype: float64
